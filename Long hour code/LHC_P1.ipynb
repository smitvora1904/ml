# %%
import numpy as np  #does mathematical operation
import matplotlib.pyplot as plt #For plotting the graphs
import pandas as pd #making the data frames and import the csv files

# %%
from google.colab import drive #to import the google drive data
drive.mount('/content/drive')   # to mount the drive data into the colab cloud and enter the activation code
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/"My Drive/Colab Notebooks/LHC-P1"
# Out:
# /content/drive/My Drive/Colab Notebooks/LHC-P1

# %% [markdown]
# # TASK-1

# %%
data_death = pd.read_csv("time_series_covid19_deaths_global.csv")
data_recovered = pd.read_csv("time_series_covid19_recovered_global.csv")
data_confirmed =   pd.read_csv("time_series_covid19_confirmed_global.csv")

data_death = pd.DataFrame(data_death)
data_recovered = pd.DataFrame(data_recovered)
data_confirmed = pd.DataFrame(data_confirmed)

# %%
data_death_india = data_death.loc[data_death['Country/Region']=='India']
data_death_india = data_death_india.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
data_death_india.index = ["Deaths"]

# %%
new_df = data_death_india.transpose()

# %%
data_recovered_india = data_recovered.loc[data_recovered['Country/Region'] == 'India']
data_recovered_india = data_recovered_india.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
data_recovered_india.index = ["recovered"]
temp = data_recovered_india.transpose()
new_df['recovered'] = temp

# %%
data_confirmed_india = data_confirmed.loc[data_confirmed['Country/Region'] == 'India']
data_confirmed_india = data_confirmed_india.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
data_confirmed_india.index = ["confirmed"]
temp = data_confirmed_india.transpose()
new_df['confirmed'] = temp

# %%
new_df
# Out:
#          Deaths  recovered  confirmed
# 1/22/20       0          0          0
# 1/23/20       0          0          0
# 1/24/20       0          0          0
# 1/25/20       0          0          0
# 1/26/20       0          0          0
# ...         ...        ...        ...
# 4/29/21  208330   15384418   18762976
# 4/30/21  211853   15684406   19164969
# 5/1/21   215542   15992271   19557457
# 5/2/21   218959   16292725   19925517
# 5/3/21   218959   16293003   19925604
#
# [468 rows x 3 columns]

# %%
plt.plot(new_df.index, new_df['Deaths'], label = "Deaths")
plt.plot(new_df.index, new_df['recovered'], label = "recovered")
plt.plot(new_df.index, new_df['confirmed'], label = "confirmed")
plt.xlabel("Days ")
plt.ylabel("Cases Death,Recovered,Confirmed")
plt.title("India Covid-19 from 22-jan to today")
plt.legend()
plt.show()

# %% [markdown]
# # TASK -2

# %%
#For US :-
data_death_US = data_death.loc[data_death['Country/Region']=='US']
data_death_US = data_death_US.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
data_death_US.index = ["Deaths"]

new_df_us = data_death_US.transpose()

data_recovered_US = data_recovered.loc[data_recovered['Country/Region'] == 'US']
data_recovered_US = data_recovered_US.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
data_recovered_US.index = ["recovered"]
temp2 = data_recovered_US.transpose()
new_df_us['recovered'] = temp2

data_confirmed_US = data_confirmed.loc[data_confirmed['Country/Region'] == 'US']
data_confirmed_US = data_confirmed_US.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
data_confirmed_US.index = ["confirmed"]
temp2 = data_confirmed_US.transpose()
new_df_us['confirmed'] = temp2

new_df_us = new_df_us.head(327)

plt.plot(new_df_us.index, new_df_us['Deaths'], label = "Deaths")
plt.plot(new_df_us.index, new_df_us['recovered'], label = "recovered")
plt.plot(new_df_us.index, new_df_us['confirmed'], label = "confirmed")
plt.xlabel("Days ")
plt.ylabel("Cases Death,Recovered,Confirmed")
plt.title("US Covid-19 from 22-jan to today")
plt.legend()
plt.show()

# %%
#For ITALY :-
data_death_ITALY = data_death.loc[data_death['Country/Region']=='Italy']
data_death_ITALY = data_death_ITALY.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
data_death_ITALY.index = ["Deaths"]

new_df_Italy = data_death_ITALY.transpose()

data_recovered_ITALY = data_recovered.loc[data_recovered['Country/Region'] == 'Italy']
data_recovered_ITALY = data_recovered_ITALY.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
data_recovered_ITALY.index = ["recovered"]
temp3 = data_recovered_ITALY.transpose()
new_df_Italy['recovered'] = temp3

data_confirmed_ITALY = data_confirmed.loc[data_confirmed['Country/Region'] == 'Italy']
data_confirmed_ITALY = data_confirmed_ITALY.drop(['Province/State', 'Country/Region','Lat','Long'], axis = 1)
data_confirmed_ITALY.index = ["confirmed"]
temp3 = data_confirmed_ITALY.transpose()
new_df_Italy['confirmed'] = temp3

plt.plot(new_df_Italy.index, new_df_Italy['Deaths'], label = "Deaths")
plt.plot(new_df_Italy.index, new_df_Italy['recovered'], label = "recovered")
plt.plot(new_df_Italy.index, new_df_Italy['confirmed'], label = "confirmed")
plt.xlabel("Days ")
plt.ylabel("Cases Death,Recovered,Confirmed")
plt.title("ITALY Covid-19 from 22-jan to today")
plt.legend()
plt.show()

# %% [markdown]
# # Train the ML model with the hypothesis of regression for India and predict the number of  covid cases on 4th May, 2021 (i.e. Today)

# %%
plt.plot(new_df.index, new_df['confirmed'], label = "confirmed")
plt.xlabel("Days ")
plt.ylabel("Cases Confirmed")
plt.title("India Covid-19 from 22-jan to today")
plt.legend()
plt.show()

# %%
data_pred = [i for i in range(1,469)]
df = new_df

# %%
df.insert(0,"Days",data_pred,True)

# %%
df
# Out:
#          Days  Deaths  recovered  confirmed
# 1/22/20     1       0          0          0
# 1/23/20     2       0          0          0
# 1/24/20     3       0          0          0
# 1/25/20     4       0          0          0
# 1/26/20     5       0          0          0
# ...       ...     ...        ...        ...
# 4/29/21   464  208330   15384418   18762976
# 4/30/21   465  211853   15684406   19164969
# 5/1/21    466  215542   15992271   19557457
# 5/2/21    467  218959   16292725   19925517
# 5/3/21    468  218959   16293003   19925604
#
# [468 rows x 4 columns]

# %%
X_features = df.iloc[:,0:1]
Y_features = df.iloc[:,-1]

# %%
from sklearn.linear_model import LinearRegression
prediction_model = LinearRegression().fit(X_features, Y_features)
x = np.array([469]).reshape(-1, 1)
x
# Out:
# array([[469]])

# %%
y_pred = prediction_model.predict(x)
print(int(y_pred))
# Out:
# 14221178

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 6)
X_poly = poly.fit_transform(X_features)
poly = poly.fit(X_poly, Y_features)
lin2 = LinearRegression()
lin2.fit(X_poly, Y_features)
x11 = np.array([469]).reshape(-1, 1)
x12 = np.array([468]).reshape(-1, 1)
ans11 = int(lin2.predict(poly.fit_transform(x11)))
ans12 = int(lin2.predict(poly.fit_transform(x12)))
print(ans11)  #19925604
print(ans12)  #19925604
# Out:
# 20000371
# 19640429

# %%
print("Total Case on 4th May in India : ",(ans11 - ans12))
fin_ind = ans11-ans12
# Out:
# Total Case on 4th May in India :  359942

# %% [markdown]
# # Task 4

# %%
import os
import glob
import pandas as pd

location = "Data_March_April"

file_name = []
for file in os.listdir(location):
         file_name.append(file)
         
print(file_name)

#combine all files in the list
combined_csv = pd.concat([pd.read_csv("Data_March_April/"+f) for f in file_name ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
# Out:
# ['03-04-2021.csv', '03-09-2021.csv', '03-06-2021.csv', '03-03-2021.csv', '03-05-2021.csv', '03-02-2021.csv', '03-01-2021.csv', '04-04-2021.csv', '03-28-2021.csv', '04-01-2021.csv', '03-30-2021.csv', '03-26-2021.csv', '03-31-2021.csv', '03-29-2021.csv', '03-27-2021.csv', '03-25-2021.csv', '03-21-2021.csv', '03-23-2021.csv', '03-20-2021.csv', '03-22-2021.csv', '03-24-2021.csv', '03-19-2021.csv', '03-16-2021.csv', '03-18-2021.csv', '03-15-2021.csv', '03-17-2021.csv', '03-14-2021.csv', '03-13-2021.csv', '03-11-2021.csv', '03-08-2021.csv', '03-10-2021.csv', '03-12-2021.csv', '03-07-2021.csv', '04-23-2021.csv', '04-20-2021.csv', '04-26-2021.csv', '04-24-2021.csv', '04-25-2021.csv', '04-22-2021.csv', '04-21-2021.csv', '04-19-2021.csv', '04-14-2021.csv', '04-17-2021.csv', '04-18-2021.csv', '04-13-2021.csv', '04-16-2021.csv', '04-10-2021.csv', '04-15-2021.csv', '04-12-2021.csv', '04-09-2021.csv', '04-11-2021.csv', '04-08-2021.csv', '04-07-2021.csv', '04-06-2021.csv', '04-03-2021.csv', '04-05-
# ...

# %%
combined_csv
# Out:
#       FIPS Admin2  ... Incident_Rate Case_Fatality_Ratio
# 0      NaN    NaN  ...    143.276077            4.385477
# 1      NaN    NaN  ...   3840.468413            1.697415
# 2      NaN    NaN  ...    259.425984            2.638866
# 3      NaN    NaN  ...  14205.655860            1.020408
# 4      NaN    NaN  ...     63.837488            2.435537
# ...    ...    ...  ...           ...                 ...
# 3978   NaN    NaN  ...      3.008057            1.195355
# 3979   NaN    NaN  ...   5811.366883            1.095925
# 3980   NaN    NaN  ...     21.179531           19.407947
# 3981   NaN    NaN  ...    498.184395            1.365929
# 3982   NaN    NaN  ...    257.398829            4.095982
#
# [254912 rows x 14 columns]

# %%
data_india = combined_csv.loc[combined_csv['Country_Region']=='India']

# %%
data_india_gujrat = data_india.loc[data_india['Province_State']=='Gujarat']

# %%
data_india_gujrat.head(10)
data_india_gujrat = data_india_gujrat.sort_values(by=['Last_Update'])
data_india_gujrat
# Out:
#      FIPS Admin2  ... Incident_Rate Case_Fatality_Ratio
# 259   NaN    NaN  ...    423.212537            1.631424
# 259   NaN    NaN  ...    423.923329            1.629058
# 259   NaN    NaN  ...    424.666999            1.626574
# 259   NaN    NaN  ...    425.418497            1.623700
# 259   NaN    NaN  ...    426.224792            1.620996
# ..    ...    ...  ...           ...                 ...
# 259   NaN    NaN  ...    866.057967            1.267237
# 259   NaN    NaN  ...    888.923868            1.265109
# 259   NaN    NaN  ...    910.603029            1.264563
# 259   NaN    NaN  ...    930.921665            1.262693
# 259   NaN    NaN  ...    930.921665            1.262693
#
# [64 rows x 14 columns]

# %%
plt.plot(data_india_gujrat['Last_Update'], data_india_gujrat['Deaths'], label = "Deaths")
plt.plot(data_india_gujrat['Last_Update'], data_india_gujrat['Recovered'], label = "recovered")
plt.plot(data_india_gujrat['Last_Update'], data_india_gujrat['Confirmed'], label = "confirmed")
plt.xlabel("Days ")
plt.ylabel("Cases Death,Recovered,Confirmed")
plt.title("India,Gujrat Covid-19 from 01-march-21 to Yesterday")
plt.legend()
plt.show()

# %% [markdown]
# # TASK - 5

# %%
data_pred_guj = [i for i in range(1,65)]
df2 = data_india_gujrat
df2.insert(0,"Days",data_pred_guj,True)
print(df2)
# Out:
#      Days  FIPS Admin2  ...    Combined_Key Incident_Rate Case_Fatality_Ratio
# 259     1   NaN    NaN  ...  Gujarat, India    423.212537            1.631424
# 259     2   NaN    NaN  ...  Gujarat, India    423.923329            1.629058
# 259     3   NaN    NaN  ...  Gujarat, India    424.666999            1.626574
# 259     4   NaN    NaN  ...  Gujarat, India    425.418497            1.623700
# 259     5   NaN    NaN  ...  Gujarat, India    426.224792            1.620996
# ..    ...   ...    ...  ...             ...           ...                 ...
# 259    60   NaN    NaN  ...  Gujarat, India    866.057967            1.267237
# 259    61   NaN    NaN  ...  Gujarat, India    888.923868            1.265109
# 259    62   NaN    NaN  ...  Gujarat, India    910.603029            1.264563
# 259    63   NaN    NaN  ...  Gujarat, India    930.921665            1.262693
# 259    64   NaN    NaN  ...  Gujarat, India    930.921665            1.262693
#
# [64 rows x 15 columns]

# %%
X_features = df2.iloc[:,0:1]
Y_features = df2.iloc[:,8:9]

print(Y_features)
# Out:
#      Confirmed
# 259     270316
# 259     270770
# 259     271245
# 259     271725
# 259     272240
# ..         ...
# 259     553172
# 259     567777
# 259     581624
# 259     594602
# 259     594602
#
# [64 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
prediction_model = LinearRegression().fit(X_features, Y_features)
x = np.array([65]).reshape(-1, 1)
x

y_pred_gujrat = prediction_model.predict(x)
print(int(y_pred_gujrat))
# Out:
# 505455

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree = 4)
X_poly = poly.fit_transform(X_features)
poly = poly.fit(X_poly, Y_features)
lin2 = LinearRegression()
lin2.fit(X_poly, Y_features)
x = np.array([65]).reshape(-1, 1)
x2 = np.array([64]).reshape(-1, 1)
ans2 =int(lin2.predict(poly.fit_transform(x))) 
ans3 =int(lin2.predict(poly.fit_transform(x2))) 
print(ans2)
print(ans3)
# Out:
# 634431
# 615651

# %%
print("Total Case in gujrat on 4th May : ",(ans2-ans3))
fin_guj = ans2-ans3
# Out:
# Total Case in gujrat on 4th May :  18780

# %% [markdown]
# # Task - 6

# %%
perct = float((fin_guj/(fin_ind))*100)
print("INdia : ",fin_ind)
print("Gujrat : ",fin_guj)
print(perct)
plt.pie([perct,100-perct],labels=['Gujarat','(India - Gujrat)'],colors=["green","pink"],
        explode=(0.1,0),shadow=True,autopct='%1.1f%%')
plt.title("Covid cases on 4th May")
plt.legend()
plt.show()
# Out:
# INdia :  359942
# Gujrat :  18780
# 5.21750726505937

# %% [markdown]
# #TASK - 7

# %%
data_india_Bengal = data_india.loc[data_india['Province_State']=='West Bengal']
data_india_Bengal = data_india_Bengal.sort_values(by=['Last_Update'])

# %%
data_india_bengal_1mar_1apr = data_india_Bengal.head(31)
data_india_bengal_1apr_1may = data_india_Bengal.iloc[31:61,:]

# %%
fig,axes=plt.subplots(figsize=(12,6),nrows=1,ncols=2)

axes[0].plot(data_india_bengal_1mar_1apr['Last_Update'],data_india_bengal_1mar_1apr['Confirmed'],color='b')
axes[0].set_xlabel('date')
axes[0].set_ylabel('no of cases')
axes[0].set_title('1 Mar - 1 April')

axes[1].plot(data_india_bengal_1apr_1may['Last_Update'],data_india_bengal_1apr_1may['Confirmed'],color='g')
axes[1].set_xlabel('date')
axes[1].set_ylabel('no of cases')
axes[1].set_title('1 April - 1 May')

plt.tight_layout()

# %% [markdown]
# # TASK - 8

# %%
import seaborn as sns
#March Month :
data_india_march = data_india.loc[data_india['Last_Update']=='2021-03-02 05:23:30']
data_india_march.head(20)
data_india_march.reset_index(inplace = True)
Maxi=data_india_march.sort_values(by=['Confirmed'],ascending=False)
Maxi

fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=Maxi.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="March Month Top 20 States Infected")
plt.show()

# %%
import seaborn as sns
#april Month :
data_india_april = data_india.loc[data_india['Last_Update']=='2021-04-01 04:27:05']
data_india_april.head(20)
data_india_april.reset_index(inplace = True)
Maxi2=data_india_april.sort_values(by=['Confirmed'],ascending=False)
Maxi2

fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=Maxi2.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="April Month Top 20 States Infected")
plt.show()

# %%
import seaborn as sns
#May Month :
data_india_May = data_india.loc[data_india['Last_Update']=='2021-05-01 04:20:47']
data_india_May.head(20)
data_india_May.reset_index(inplace = True)
Maxi3=data_india_May.sort_values(by=['Confirmed'],ascending=False)
Maxi3

fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=Maxi3.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="May Month Top 20 States Infected")
plt.show()

# %%
import seaborn as sns
#May Month :
data_india_march_mid = data_india.loc[data_india['Last_Update']=='2021-03-15 05:25:51']
data_india_march_mid.head(20)
data_india_march_mid.reset_index(inplace = True)
Maxi4=data_india_march_mid.sort_values(by=['Confirmed'],ascending=False)
Maxi4

fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=Maxi4.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="March Mid Month Top 20 States Infected")
plt.show()

# %%
import seaborn as sns

data_india_april_mid = data_india.loc[data_india['Last_Update']=='2021-04-15 04:20:54']
data_india_april_mid.head(20)
data_india_april_mid.reset_index(inplace = True)
Maxi5=data_india_april_mid.sort_values(by=['Confirmed'],ascending=False)
Maxi5

fig,ax = plt.subplots(figsize=(20,7))
ax.set_xticklabels(ax.get_xticklabels(), rotation=40, ha="right")
sns.barplot(ax=ax,x="Province_State",y="Confirmed",data=Maxi5.head(20),dodge=False)
ax.set(xlabel="States", ylabel = "Total Cases",title="April Mid Month Top 20 States Infected")
plt.show()
